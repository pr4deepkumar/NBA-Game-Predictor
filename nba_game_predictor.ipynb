# %% [markdown]
# ## NBA Game Predictor
#
# This project is designed to predict the winner in a potential matchup

# %% [markdown]
# Let us import the API to be used

# %%
# %pip install nba-api
# Out:
# Requirement already satisfied: nba-api in /opt/anaconda3/lib/python3.12/site-packages (1.10.0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from nba-api) (1.26.4)
# Requirement already satisfied: pandas>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from nba-api) (2.2.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /opt/anaconda3/lib/python3.12/site-packages (from nba-api) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=2.2.0->nba-api) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=2.2.0->nba-api) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=2.2.0->nba-api) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.3->nba-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.3->nba-api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.3->nba-api) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.3->nba-api) (2025.7.14)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nba-api) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now, we shall import the necessary packages

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# for classification
import xgboost as xgb
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import loguniform

# for metrics
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Games Predictor

# %%
from nba_api.stats.endpoints import leaguegamefinder
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable="10/22/2024",league_id_nullable="00")
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0     42024  1610612760               OKC  Oklahoma City Thunder  0042400407
# 1     42024  1610612754               IND         Indiana Pacers  0042400407
# 2     42024  1610612760               OKC  Oklahoma City Thunder  0042400406
# 3     42024  1610612754               IND         Indiana Pacers  0042400406
# 4     42024  1610612754               IND         Indiana Pacers  0042400405
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 0  2025-06-22  OKC vs. IND  W  240  103   35   87   0.402    11    40
# 1  2025-06-22    IND @ OKC  L  240   91   29   70   0.414    11    28
# 2  2025-06-19    OKC @ IND  L  240   91   31   74   0.419     8    30
# 3  2025-06-19  IND vs. OKC  W  240  108   38   92   0.413    15    42
# 4  2025-06-16    IND @ OKC  L  241  109   37   82   0.451    11    30
#
#    FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0    0.275   22   31   0.710    13    27   40   20   14    8    7  23
# 1    0.393   22   29   0.759    12    33   45   17    6    4   21  24
# 2    0.267   21   26   0.808     4    37   41   14    4    4   21  20
# 3    0.357   17   25   0.680    11    35   46   23   16    5   10  17
# 4    0.367   24   30   0.800    18    32   50   23    9    4   22  25
#
#    PLUS_MINUS
# 0        12.0
# 1       -12.0
# 2       -17.0
# 3        17.0
# 4       -11.0

# %%
games.columns
# Out:
# Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')

# %%
games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]

# %%
games
# Out:
#                    TEAM_NAME     GAME_ID   GAME_DATE      MATCHUP WL  \
# 0      Oklahoma City Thunder  0042400407  2025-06-22  OKC vs. IND  W
# 1             Indiana Pacers  0042400407  2025-06-22    IND @ OKC  L
# 2      Oklahoma City Thunder  0042400406  2025-06-19    OKC @ IND  L
# 3             Indiana Pacers  0042400406  2025-06-19  IND vs. OKC  W
# 4             Indiana Pacers  0042400405  2025-06-16    IND @ OKC  L
# ...                      ...         ...         ...          ... ..
# 2651         Milwaukee Bucks  0022400066  2024-10-23    MIL @ PHI  W
# 2652          Boston Celtics  0022400061  2024-10-22  BOS vs. NYK  W
# 2653      Los Angeles Lakers  0022400062  2024-10-22  LAL vs. MIN  W
# 2654         New York Knicks  0022400061  2024-10-22    NYK @ BOS  L
# 2655  Minnesota Timberwolves  0022400062  2024-10-22    MIN @ LAL  L
#
#       PLUS_MINUS
# 0           12.0
# 1          -12.0
# 2          -17.0
# 3           17.0
# 4          -11.0
# ...          ...
# 2651        15.0
# 2652        23.0
# 2653         7.0
# 2654       -23.0
# 2655        -7.0
#
# [2656 rows x 6 columns]

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2656 entries, 0 to 2655
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TEAM_NAME   2656 non-null   object
#  1   GAME_ID     2656 non-null   object
#  2   GAME_DATE   2656 non-null   object
#  3   MATCHUP     2656 non-null   object
#  4   WL          2656 non-null   object
#  5   PLUS_MINUS  2656 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 124.6+ KB

# %%
games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

# %%
games['GAME_DATE']
# Out:
# 0      2025-06-22
# 1      2025-06-22
# 2      2025-06-19
# 3      2025-06-19
# 4      2025-06-16
#           ...
# 2651   2024-10-23
# 2652   2024-10-22
# 2653   2024-10-22
# 2654   2024-10-22
# 2655   2024-10-22
# Name: GAME_DATE, Length: 2656, dtype: datetime64[ns]

# %%
games = games.sort_values('GAME_DATE')
games
# Out:
#                    TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  \
# 2655  Minnesota Timberwolves  0022400062 2024-10-22    MIN @ LAL  L
# 2652          Boston Celtics  0022400061 2024-10-22  BOS vs. NYK  W
# 2654         New York Knicks  0022400061 2024-10-22    NYK @ BOS  L
# 2653      Los Angeles Lakers  0022400062 2024-10-22  LAL vs. MIN  W
# 2651         Milwaukee Bucks  0022400066 2024-10-23    MIL @ PHI  W
# ...                      ...         ...        ...          ... ..
# 4             Indiana Pacers  0042400405 2025-06-16    IND @ OKC  L
# 3             Indiana Pacers  0042400406 2025-06-19  IND vs. OKC  W
# 2      Oklahoma City Thunder  0042400406 2025-06-19    OKC @ IND  L
# 1             Indiana Pacers  0042400407 2025-06-22    IND @ OKC  L
# 0      Oklahoma City Thunder  0042400407 2025-06-22  OKC vs. IND  W
#
#       PLUS_MINUS
# 2655        -7.0
# 2652        23.0
# 2654       -23.0
# 2653         7.0
# 2651        15.0
# ...          ...
# 4          -11.0
# 3           17.0
# 2          -17.0
# 1          -12.0
# 0           12.0
#
# [2656 rows x 6 columns]

# %%
games['avg_30_plus_minus'] = games.groupby('TEAM_NAME')['PLUS_MINUS'].transform(lambda x: x.rolling(30, closed='left').mean())

# %%
games
# Out:
#                    TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  \
# 2655  Minnesota Timberwolves  0022400062 2024-10-22    MIN @ LAL  L
# 2652          Boston Celtics  0022400061 2024-10-22  BOS vs. NYK  W
# 2654         New York Knicks  0022400061 2024-10-22    NYK @ BOS  L
# 2653      Los Angeles Lakers  0022400062 2024-10-22  LAL vs. MIN  W
# 2651         Milwaukee Bucks  0022400066 2024-10-23    MIL @ PHI  W
# ...                      ...         ...        ...          ... ..
# 4             Indiana Pacers  0042400405 2025-06-16    IND @ OKC  L
# 3             Indiana Pacers  0042400406 2025-06-19  IND vs. OKC  W
# 2      Oklahoma City Thunder  0042400406 2025-06-19    OKC @ IND  L
# 1             Indiana Pacers  0042400407 2025-06-22    IND @ OKC  L
# 0      Oklahoma City Thunder  0042400407 2025-06-22  OKC vs. IND  W
#
#       PLUS_MINUS  avg_30_plus_minus
# 2655        -7.0                NaN
# 2652        23.0                NaN
# 2654       -23.0                NaN
# 2653         7.0                NaN
# 2651        15.0                NaN
# ...          ...                ...
# 4          -11.0           4.533333
# 3           17.0           2.400000
# 2          -17.0           9.966667
# 1          -12.0           3.666667
# 0           12.0           8.700000
#
# [2656 rows x 7 columns]

# %%
games[games['TEAM_NAME']=='Los Angeles Lakers'].head(35)
# Out:
#                TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  PLUS_MINUS  \
# 2653  Los Angeles Lakers  0022400062 2024-10-22  LAL vs. MIN  W         7.0
# 2623  Los Angeles Lakers  0022400085 2024-10-25  LAL vs. PHX  W         7.0
# 2588  Los Angeles Lakers  0022400096 2024-10-26  LAL vs. SAC  W         4.0
# 2553  Los Angeles Lakers  0022400111 2024-10-28    LAL @ PHX  L        -4.0
# 2531  Los Angeles Lakers  0022400118 2024-10-30    LAL @ CLE  L       -24.0
# 2503  Los Angeles Lakers  0022400137 2024-11-01    LAL @ TOR  W         6.0
# 2454  Los Angeles Lakers  0022400156 2024-11-04    LAL @ DET  L       -12.0
# 2436  Los Angeles Lakers  0022400174 2024-11-06    LAL @ MEM  L       -17.0
# 2407  Los Angeles Lakers  0022400195 2024-11-08  LAL vs. PHI  W        10.0
# 2368  Los Angeles Lakers  0022400211 2024-11-10  LAL vs. TOR  W        20.0
# 2314  Los Angeles Lakers  0022400225 2024-11-13  LAL vs. MEM  W         5.0
# 2290  Los Angeles Lakers  0022400015 2024-11-15    LAL @ SAS  W         5.0
# 2273  Los Angeles Lakers  0022400231 2024-11-16    LAL @ NOP  W         5.0
# 2224  Los Angeles Lakers  0022400026 2024-11-19  LAL vs. UTA  W         6.0
# 2201  Los Angeles Lakers  0022400263 2024-11-21  LAL vs. ORL  L        -1.0
# 2171  Los Angeles Lakers  0022400270 2024-11-23  LAL vs. DEN  L       -25.0
# 2135  Los Angeles Lakers  0022400039 2024-11-26    LAL @ PHX  L       -27.0
# 2104  Los Angeles Lakers  0022400296 2024-11-27    LAL @ SAS  W        18.0
# 2093  Los Angeles Lakers  0022400048 2024-11-29  LAL vs. OKC  L        -8.0
# 2060  Los Angeles Lakers  0022400311 2024-12-01    LAL @ UTA  W         1.0
# 2047  Los Angeles Lakers  0022400318 2024-12-02    LAL @ MIN  L       -29.0
# 2014  Los Angeles Lakers  0022400321 2024-12-04    LAL @ MIA  L       -41.0
# 1986  Los Angeles Lakers  0022400334 2024-12-06    LAL @ ATL  L        -2.0
# 1951  Los Angeles Lakers  0022400358 2024-12-08  LAL vs. POR  W         9.0
# 1923  Los Angeles Lakers  0022401210 2024-12-13    LAL @ MIN  L       -10.0
# 1899  Los Angeles Lakers  0022401220 2024-12-15  LAL vs. MEM  W         6.0
# 1851  Los Angeles Lakers  0022400372 2024-12-19    LAL @ SAC  W        13.0
# 1826  Los Angeles Lakers  0022400376 2024-12-21    LAL @ SAC  W         4.0
# 1787  Los Angeles Lakers  0022400404 2024-12-23  LAL vs. DET  L        -3.0
# 1777  Los Angeles Lakers  0022400408 2024-12-25    LAL @ GSW  W         2.0
# 1727  Los Angeles Lakers  0022400435 2024-12-28  LAL vs. SAC  W        10.0
# 1687  Los Angeles Lakers  0022400454 2024-12-31  LAL vs. CLE  L       -12.0
# 1667  Los Angeles Lakers  0022400468 2025-01-02  LAL vs. POR  W         8.0
# 1647  Los Angeles Lakers  0022400477 2025-01-03  LAL vs. ATL  W        17.0
# 1620  Los Angeles Lakers  0022400491 2025-01-05    LAL @ HOU  L        -4.0
#
#       avg_30_plus_minus
# 2653                NaN
# 2623                NaN
# 2588                NaN
# 2553                NaN
# 2531                NaN
# 2503                NaN
# 2454                NaN
# 2436                NaN
# 2407                NaN
# 2368                NaN
# 2314                NaN
# 2290                NaN
# 2273                NaN
# 2224                NaN
# 2201                NaN
# 2171                NaN
# 2135                NaN
# 2104                NaN
# 2093                NaN
# 2060                NaN
# 2047                NaN
# 2014                NaN
# 1986                NaN
# 1951                NaN
# 1923                NaN
# 1899                NaN
# 1851                NaN
# 1826                NaN
# 1787                NaN
# 1777                NaN
# 1727          -2.500000
# 1687          -2.400000
# 1667          -3.033333
# 1647          -2.900000
# 1620          -2.200000

# %%
msk = games['MATCHUP'].str.contains('@')
games_away = games[msk]
games_home = games[~msk]

# %%
games_home.shape
# Out:
# (1322, 7)

# %%
games_away.shape
# Out:
# (1334, 7)

# %%
games_home
# Out:
#                   TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  \
# 2652         Boston Celtics  0022400061 2024-10-22  BOS vs. NYK  W
# 2653     Los Angeles Lakers  0022400062 2024-10-22  LAL vs. MIN  W
# 2632        Houston Rockets  0022400068 2024-10-23  HOU vs. CHA  L
# 2637     Philadelphia 76ers  0022400066 2024-10-23  PHI vs. MIL  L
# 2638          Atlanta Hawks  0022400064 2024-10-23  ATL vs. BKN  W
# ...                     ...         ...        ...          ... ..
# 8            Indiana Pacers  0042400403 2025-06-11  IND vs. OKC  W
# 7            Indiana Pacers  0042400404 2025-06-13  IND vs. OKC  L
# 5     Oklahoma City Thunder  0042400405 2025-06-16  OKC vs. IND  W
# 3            Indiana Pacers  0042400406 2025-06-19  IND vs. OKC  W
# 0     Oklahoma City Thunder  0042400407 2025-06-22  OKC vs. IND  W
#
#       PLUS_MINUS  avg_30_plus_minus
# 2652        23.0                NaN
# 2653         7.0                NaN
# 2632        -5.0                NaN
# 2637       -15.0                NaN
# 2638         4.0                NaN
# ...          ...                ...
# 8            9.0           4.966667
# 7           -7.0           4.733333
# 5           11.0          10.300000
# 3           17.0           2.400000
# 0           12.0           8.700000
#
# [1322 rows x 7 columns]

# %%
games_away
# Out:
#                    TEAM_NAME     GAME_ID  GAME_DATE    MATCHUP WL  PLUS_MINUS  \
# 2655  Minnesota Timberwolves  0022400062 2024-10-22  MIN @ LAL  L        -7.0
# 2654         New York Knicks  0022400061 2024-10-22  NYK @ BOS  L       -23.0
# 2651         Milwaukee Bucks  0022400066 2024-10-23  MIL @ PHI  W        15.0
# 2634     Cleveland Cavaliers  0022400067 2024-10-23  CLE @ TOR  W        30.0
# 2635       Memphis Grizzlies  0022400070 2024-10-23  MEM @ UTA  W         2.0
# ...                      ...         ...        ...        ... ..         ...
# 9      Oklahoma City Thunder  0042400403 2025-06-11  OKC @ IND  L        -9.0
# 6      Oklahoma City Thunder  0042400404 2025-06-13  OKC @ IND  W         7.0
# 4             Indiana Pacers  0042400405 2025-06-16  IND @ OKC  L       -11.0
# 2      Oklahoma City Thunder  0042400406 2025-06-19  OKC @ IND  L       -17.0
# 1             Indiana Pacers  0042400407 2025-06-22  IND @ OKC  L       -12.0
#
#       avg_30_plus_minus
# 2655                NaN
# 2654                NaN
# 2651                NaN
# 2634                NaN
# 2635                NaN
# ...                 ...
# 9             10.966667
# 6             10.600000
# 4              4.533333
# 2              9.966667
# 1              3.666667
#
# [1334 rows x 7 columns]

# %%
games_merged = pd.merge(games_home, games_away, on='GAME_ID', suffixes=('_home', '_away'))
games_merged
# Out:
#              TEAM_NAME_home     GAME_ID GAME_DATE_home MATCHUP_home WL_home  \
# 0            Boston Celtics  0022400061     2024-10-22  BOS vs. NYK       W
# 1        Los Angeles Lakers  0022400062     2024-10-22  LAL vs. MIN       W
# 2           Houston Rockets  0022400068     2024-10-23  HOU vs. CHA       L
# 3        Philadelphia 76ers  0022400066     2024-10-23  PHI vs. MIL       L
# 4             Atlanta Hawks  0022400064     2024-10-23  ATL vs. BKN       W
# ...                     ...         ...            ...          ...     ...
# 1317         Indiana Pacers  0042400403     2025-06-11  IND vs. OKC       W
# 1318         Indiana Pacers  0042400404     2025-06-13  IND vs. OKC       L
# 1319  Oklahoma City Thunder  0042400405     2025-06-16  OKC vs. IND       W
# 1320         Indiana Pacers  0042400406     2025-06-19  IND vs. OKC       W
# 1321  Oklahoma City Thunder  0042400407     2025-06-22  OKC vs. IND       W
#
#       PLUS_MINUS_home  avg_30_plus_minus_home          TEAM_NAME_away  \
# 0                23.0                     NaN         New York Knicks
# 1                 7.0                     NaN  Minnesota Timberwolves
# 2                -5.0                     NaN       Charlotte Hornets
# 3               -15.0                     NaN         Milwaukee Bucks
# 4                 4.0                     NaN           Brooklyn Nets
# ...               ...                     ...                     ...
# 1317              9.0                4.966667   Oklahoma City Thunder
# 1318             -7.0                4.733333   Oklahoma City Thunder
# 1319             11.0               10.300000          Indiana Pacers
# 1320             17.0                2.400000   Oklahoma City Thunder
# 1321             12.0                8.700000          Indiana Pacers
#
#      GAME_DATE_away MATCHUP_away WL_away  PLUS_MINUS_away  \
# 0        2024-10-22    NYK @ BOS       L            -23.0
# 1        2024-10-22    MIN @ LAL       L             -7.0
# 2        2024-10-23    CHA @ HOU       W              5.0
# 3        2024-10-23    MIL @ PHI       W             15.0
# 4        2024-10-23    BKN @ ATL       L             -4.0
# ...             ...          ...     ...              ...
# 1317     2025-06-11    OKC @ IND       L             -9.0
# 1318     2025-06-13    OKC @ IND       W              7.0
# 1319     2025-06-16    IND @ OKC       L            -11.0
# 1320     2025-06-19    OKC @ IND       L            -17.0
# 1321     2025-06-22    IND @ OKC       L            -12.0
#
#       avg_30_plus_minus_away
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 1317               10.966667
# 1318               10.600000
# 1319                4.533333
# 1320                9.966667
# 1321                3.666667
#
# [1322 rows x 13 columns]

# %%
games_merged['avg_30_plus_minus_diff'] = games_merged['avg_30_plus_minus_home'] - games_merged['avg_30_plus_minus_away']

# %%
games_merged
# Out:
#              TEAM_NAME_home     GAME_ID GAME_DATE_home MATCHUP_home WL_home  \
# 0            Boston Celtics  0022400061     2024-10-22  BOS vs. NYK       W
# 1        Los Angeles Lakers  0022400062     2024-10-22  LAL vs. MIN       W
# 2           Houston Rockets  0022400068     2024-10-23  HOU vs. CHA       L
# 3        Philadelphia 76ers  0022400066     2024-10-23  PHI vs. MIL       L
# 4             Atlanta Hawks  0022400064     2024-10-23  ATL vs. BKN       W
# ...                     ...         ...            ...          ...     ...
# 1317         Indiana Pacers  0042400403     2025-06-11  IND vs. OKC       W
# 1318         Indiana Pacers  0042400404     2025-06-13  IND vs. OKC       L
# 1319  Oklahoma City Thunder  0042400405     2025-06-16  OKC vs. IND       W
# 1320         Indiana Pacers  0042400406     2025-06-19  IND vs. OKC       W
# 1321  Oklahoma City Thunder  0042400407     2025-06-22  OKC vs. IND       W
#
#       PLUS_MINUS_home  avg_30_plus_minus_home          TEAM_NAME_away  \
# 0                23.0                     NaN         New York Knicks
# 1                 7.0                     NaN  Minnesota Timberwolves
# 2                -5.0                     NaN       Charlotte Hornets
# 3               -15.0                     NaN         Milwaukee Bucks
# 4                 4.0                     NaN           Brooklyn Nets
# ...               ...                     ...                     ...
# 1317              9.0                4.966667   Oklahoma City Thunder
# 1318             -7.0                4.733333   Oklahoma City Thunder
# 1319             11.0               10.300000          Indiana Pacers
# 1320             17.0                2.400000   Oklahoma City Thunder
# 1321             12.0                8.700000          Indiana Pacers
#
#      GAME_DATE_away MATCHUP_away WL_away  PLUS_MINUS_away  \
# 0        2024-10-22    NYK @ BOS       L            -23.0
# 1        2024-10-22    MIN @ LAL       L             -7.0
# 2        2024-10-23    CHA @ HOU       W              5.0
# 3        2024-10-23    MIL @ PHI       W             15.0
# 4        2024-10-23    BKN @ ATL       L             -4.0
# ...             ...          ...     ...              ...
# 1317     2025-06-11    OKC @ IND       L             -9.0
# 1318     2025-06-13    OKC @ IND       W              7.0
# 1319     2025-06-16    IND @ OKC       L            -11.0
# 1320     2025-06-19    OKC @ IND       L            -17.0
# 1321     2025-06-22    IND @ OKC       L            -12.0
#
#       avg_30_plus_minus_away  avg_30_plus_minus_diff
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 1317               10.966667               -6.000000
# 1318               10.600000               -5.866667
# 1319                4.533333                5.766667
# 1320                9.966667               -7.566667
# 1321                3.666667                5.033333
#
# [1322 rows x 14 columns]

# %%
games_merged[['WL_home', 'avg_30_plus_minus_diff']]
# Out:
#      WL_home  avg_30_plus_minus_diff
# 0          W                     NaN
# 1          W                     NaN
# 2          L                     NaN
# 3          L                     NaN
# 4          W                     NaN
# ...      ...                     ...
# 1317       W               -6.000000
# 1318       L               -5.866667
# 1319       W                5.766667
# 1320       W               -7.566667
# 1321       W                5.033333
#
# [1322 rows x 2 columns]

# %%
games_model = games_merged[['WL_home', 'avg_30_plus_minus_diff']].dropna()
games_model
# Out:
#      WL_home  avg_30_plus_minus_diff
# 440        W               14.966667
# 443        L                3.966667
# 444        W                1.333333
# 447        W               10.600000
# 448        L               -3.800000
# ...      ...                     ...
# 1317       W               -6.000000
# 1318       L               -5.866667
# 1319       W                5.766667
# 1320       W               -7.566667
# 1321       W                5.033333
#
# [862 rows x 2 columns]

# %%
games_model['WL_home'] = games_model['WL_home'].map({'W': 1, 'L': 0})

# %%
games_model
# Out:
#       WL_home  avg_30_plus_minus_diff
# 440         1               14.966667
# 443         0                3.966667
# 444         1                1.333333
# 447         1               10.600000
# 448         0               -3.800000
# ...       ...                     ...
# 1317        1               -6.000000
# 1318        0               -5.866667
# 1319        1                5.766667
# 1320        1               -7.566667
# 1321        1                5.033333
#
# [862 rows x 2 columns]

# %% [markdown]
# ## Building the Model

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(games_model, stratify=games_model['WL_home'], test_size=0.2, random_state=7)

# %%
df_train.shape
# Out:
# (689, 2)

# %%
df_test.shape
# Out:
# (173, 2)

# %%
target = 'WL_home'
X_train = df_train.drop(columns=target)
y_train = df_train[target]

X_test = df_test.drop(columns=target)
y_test= df_test[target]

# %% [markdown]
# Let us use the various Classification Algorithms to identify which gives us the highest accuracy

# %%
xgb_clf = xgb.XGBClassifier(use_label_encoder=False, random_state=7)

# %%
xgb_clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = xgb_clf.predict(X_test)

# %%
xgb_score = accuracy_score(y_test, y_pred)
xgb_score
# Out:
# 0.6069364161849711

# %%
xgb_hyp_params = {'learning_rate': loguniform(0.0001, 1),
              'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
              'subsample': [0.7, 0.8, 0.9, 1.0],
              'n_estimators': [50, 100, 150, 200]}

# %%
random_hyp = RandomizedSearchCV(estimator=xgb_clf, 
                                param_distributions=xgb_hyp_params, 
                                n_iter=20, 
                                cv=7,
                                scoring='accuracy',
                                random_state=7)

# %%
random_hyp.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=7,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            feature_weights=None, gamma=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constrain...
#                                            monotone_constraints=None,
#                                            multi_strategy=None,
#                                            n_estimators=None, n_jobs=None,
#                                            num_parallel_tree=None, ...),
#                    n_iter=20,
#                    param_distributions={'learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x177af44a0>,
#                                         'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
#                                         'n_estimators': [50, 100, 150, 200],
#                                         'subsample': [0.7, 0.8, 0.9, 1.0]},
#                    random_state=7, scoring='accuracy')

# %%
random_hyp.best_params_
# Out:
# {'learning_rate': 0.025246179740589205,
#  'max_depth': 2,
#  'n_estimators': 150,
#  'subsample': 0.7}

# %%
model_hyp = random_hyp.best_estimator_

# %%
y_pred_hyp = model_hyp.predict(X_test)

# %%
rs_score = accuracy_score(y_test, y_pred_hyp)

# %%
from joblib import dump, load
dump(model_hyp, 'model_nba.joblib') 
model_saved = load('model_nba.joblib')

# %%
accuracy_score(y_test, model_saved.predict(X_test))
# Out:
# 0.6647398843930635

# %%
from nba_api.stats.endpoints import leaguegamefinder
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable="10/18/2022", league_id_nullable='00')
games = gamefinder.get_data_frames()[0]

games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]

import pandas as pd

games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

games = games.sort_values('GAME_DATE')

games['avg_30_plus_minus'] = games.groupby('TEAM_NAME')['PLUS_MINUS'].transform(lambda x: x.rolling(30, closed='left').mean())

msk = games['MATCHUP'].str.contains('@')
games_away = games[msk]
games_home = games[~msk]

games_merged = pd.merge(games_home, games_away, on='GAME_ID', suffixes=('_home', '_away'))

games_merged['avg_30_plus_minus_diff'] = games_merged['avg_30_plus_minus_home'] - games_merged['avg_30_plus_minus_away']

# %%
team_home='Toronto Raptors'
team_away='Boston Celtics'

import numpy as np
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='10/18/2022',
                                           league_id_nullable='00')
games = gamefinder.get_data_frames()[0]
games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]
games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

msk_home = (games['TEAM_NAME'] == team_home)
games_30_home = games[msk_home].sort_values('GAME_DATE').tail(30)
home_plus_minus = games_30_home['PLUS_MINUS'].mean()

msk_away = (games['TEAM_NAME'] == team_away)
games_30_away = games[msk_away].sort_values('GAME_DATE').tail(30)
away_plus_minus = games_30_away['PLUS_MINUS'].mean()

games_diff=home_plus_minus - away_plus_minus

predict_home_win=model_saved.predict(np.array([games_diff]))[0]
predict_winning_probability=model_saved.predict_proba(np.array([games_diff]))[0][1]

# %%
def predict_games(team_home, team_away):
    gamefinder = leaguegamefinder.LeagueGameFinder(
        date_from_nullable='10/18/2022',
        league_id_nullable='00')
    games = gamefinder.get_data_frames()[0]
    games = games[
        ['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]
    games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

    msk_home = (games['TEAM_NAME'] == team_home)
    games_30_home = games[msk_home].sort_values('GAME_DATE').tail(30)
    home_plus_minus = games_30_home['PLUS_MINUS'].mean()

    msk_away = (games['TEAM_NAME'] == team_away)
    games_30_away = games[msk_away].sort_values('GAME_DATE').tail(30)
    away_plus_minus = games_30_away['PLUS_MINUS'].mean()

    games_diff = home_plus_minus - away_plus_minus

    predict_home_win = model_saved.predict(np.array([games_diff]))[0]
    predict_winning_probability = model_saved.predict_proba(np.array([games_diff]))[0][1]
    return predict_home_win, predict_winning_probability

# %%
predict_games('Boston Celtics','Toronto Raptors')
# Out:
# (1, 0.8107539)
