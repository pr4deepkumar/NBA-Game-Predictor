# %% [markdown]
# ## NBA Game Predictor
#
# This project is designed to predict the winner in a potential matchup

# %% [markdown]
# Let us import the API to be used

# %%
# %pip install nba-api
# Out:
# Requirement already satisfied: nba-api in c:\users\4ltvp\anaconda3\lib\site-packages (1.1.14)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests in c:\users\4ltvp\anaconda3\lib\site-packages (from nba-api) (2.28.1)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in c:\users\4ltvp\anaconda3\lib\site-packages (from nba-api) (1.23.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\4ltvp\anaconda3\lib\site-packages (from requests->nba-api) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\4ltvp\anaconda3\lib\site-packages (from requests->nba-api) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\4ltvp\anaconda3\lib\site-packages (from requests->nba-api) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\4ltvp\anaconda3\lib\site-packages (from requests->nba-api) (1.26.11)

# %% [markdown]
# Now, we shall import the necessary packages

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# for classification
import xgboost as xgb
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils.fixes import loguniform

# for metrics
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Games Predictor

# %%
from nba_api.stats.endpoints import leaguegamefinder
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/01/2020', league_id_nullable='00')
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION            TEAM_NAME     GAME_ID  \
# 0     22022  1610612742               DAL     Dallas Mavericks  0022200362
# 1     22022  1610612765               DET      Detroit Pistons  0022200361
# 2     22022  1610612739               CLE  Cleveland Cavaliers  0022200360
# 3     22022  1610612747               LAL   Los Angeles Lakers  0022200360
# 4     22022  1610612743               DEN       Denver Nuggets  0022200362
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 0  2022-12-06    DAL @ DEN  W  239  116   36   72   0.500    17    36
# 1  2022-12-06    DET @ MIA  W  240  116   43   87   0.494    19    41
# 2  2022-12-06  CLE vs. LAL  W  241  116   48   93   0.516     7    27
# 3  2022-12-06    LAL @ CLE  L  240  102   38   89   0.427     6    36
# 4  2022-12-06  DEN vs. DAL  L  241  115   40   78   0.513    13    32
#
#    FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0    0.472   27   31   0.871     4    31   35   27   10    4   15  32
# 1    0.463   11   15   0.733     9    31   40   27    8    1   12  19
# 2    0.259   13   17   0.765     9    35   44   25   11    3    7  20
# 3    0.167   20   24   0.833    14    29   43   16    4    6   16  13
# 4    0.406   22   28   0.786     8    28   36   30    8    4   17  28
#
#    PLUS_MINUS
# 0         1.0
# 1        20.0
# 2        14.0
# 3       -14.0
# 4        -1.0

# %%
games.columns
# Out:
# Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')

# %%
games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]

# %%
games
# Out:
#                    TEAM_NAME     GAME_ID   GAME_DATE      MATCHUP WL  \
# 0           Dallas Mavericks  0022200362  2022-12-06    DAL @ DEN  W
# 1            Detroit Pistons  0022200361  2022-12-06    DET @ MIA  W
# 2        Cleveland Cavaliers  0022200360  2022-12-06  CLE vs. LAL  W
# 3         Los Angeles Lakers  0022200360  2022-12-06    LAL @ CLE  L
# 4             Denver Nuggets  0022200362  2022-12-06  DEN vs. DAL  L
# ...                      ...         ...         ...          ... ..
# 7441         New York Knicks  0021900505  2020-01-01  NYK vs. POR  W
# 7442      Washington Wizards  0021900504  2020-01-01  WAS vs. ORL  L
# 7443      Los Angeles Lakers  0021900507  2020-01-01  LAL vs. PHX  W
# 7444           Orlando Magic  0021900504  2020-01-01    ORL @ WAS  W
# 7445  Portland Trail Blazers  0021900505  2020-01-01    POR @ NYK  L
#
#       PLUS_MINUS
# 0            1.0
# 1           20.0
# 2           14.0
# 3          -14.0
# 4           -1.0
# ...          ...
# 7441        24.0
# 7442       -21.0
# 7443        10.0
# 7444        21.0
# 7445       -24.0
#
# [7446 rows x 6 columns]

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7446 entries, 0 to 7445
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TEAM_NAME   7446 non-null   object
#  1   GAME_ID     7446 non-null   object
#  2   GAME_DATE   7446 non-null   object
#  3   MATCHUP     7446 non-null   object
#  4   WL          7446 non-null   object
#  5   PLUS_MINUS  7446 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 349.2+ KB

# %%
games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

# %%
games['GAME_DATE']
# Out:
# 0      2022-12-06
# 1      2022-12-06
# 2      2022-12-06
# 3      2022-12-06
# 4      2022-12-06
#           ...
# 7441   2020-01-01
# 7442   2020-01-01
# 7443   2020-01-01
# 7444   2020-01-01
# 7445   2020-01-01
# Name: GAME_DATE, Length: 7446, dtype: datetime64[ns]

# %%
games = games.sort_values('GAME_DATE')
games
# Out:
#                    TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  \
# 7445  Portland Trail Blazers  0021900505 2020-01-01    POR @ NYK  L
# 7438         Milwaukee Bucks  0021900506 2020-01-01  MIL vs. MIN  W
# 7439            Phoenix Suns  0021900507 2020-01-01    PHX @ LAL  L
# 7440  Minnesota Timberwolves  0021900506 2020-01-01    MIN @ MIL  L
# 7444           Orlando Magic  0021900504 2020-01-01    ORL @ WAS  W
# ...                      ...         ...        ...          ... ..
# 4             Denver Nuggets  0022200362 2022-12-06  DEN vs. DAL  L
# 3         Los Angeles Lakers  0022200360 2022-12-06    LAL @ CLE  L
# 2        Cleveland Cavaliers  0022200360 2022-12-06  CLE vs. LAL  W
# 1            Detroit Pistons  0022200361 2022-12-06    DET @ MIA  W
# 0           Dallas Mavericks  0022200362 2022-12-06    DAL @ DEN  W
#
#       PLUS_MINUS
# 7445       -24.0
# 7438         2.0
# 7439       -10.0
# 7440        -2.0
# 7444        21.0
# ...          ...
# 4           -1.0
# 3          -14.0
# 2           14.0
# 1           20.0
# 0            1.0
#
# [7446 rows x 6 columns]

# %%
games['avg_30_plus_minus'] = games.groupby('TEAM_NAME')['PLUS_MINUS'].transform(lambda x: x.rolling(30, closed='left').mean())

# %%
games
# Out:
#                    TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  \
# 7445  Portland Trail Blazers  0021900505 2020-01-01    POR @ NYK  L
# 7438         Milwaukee Bucks  0021900506 2020-01-01  MIL vs. MIN  W
# 7439            Phoenix Suns  0021900507 2020-01-01    PHX @ LAL  L
# 7440  Minnesota Timberwolves  0021900506 2020-01-01    MIN @ MIL  L
# 7444           Orlando Magic  0021900504 2020-01-01    ORL @ WAS  W
# ...                      ...         ...        ...          ... ..
# 4             Denver Nuggets  0022200362 2022-12-06  DEN vs. DAL  L
# 3         Los Angeles Lakers  0022200360 2022-12-06    LAL @ CLE  L
# 2        Cleveland Cavaliers  0022200360 2022-12-06  CLE vs. LAL  W
# 1            Detroit Pistons  0022200361 2022-12-06    DET @ MIA  W
# 0           Dallas Mavericks  0022200362 2022-12-06    DAL @ DEN  W
#
#       PLUS_MINUS  avg_30_plus_minus
# 7445       -24.0                NaN
# 7438         2.0                NaN
# 7439       -10.0                NaN
# 7440        -2.0                NaN
# 7444        21.0                NaN
# ...          ...                ...
# 4           -1.0           0.513333
# 3          -14.0          -2.466667
# 2           14.0           3.926667
# 1           20.0          -9.066667
# 0            1.0           2.100000
#
# [7446 rows x 7 columns]

# %%
games[games['TEAM_NAME']=='Los Angeles Lakers'].head(35)
# Out:
#                TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  PLUS_MINUS  \
# 7443  Los Angeles Lakers  0021900507 2020-01-01  LAL vs. PHX  W        10.0
# 7416  Los Angeles Lakers  0021900522 2020-01-03  LAL vs. NOP  W        10.0
# 7378  Los Angeles Lakers  0021900538 2020-01-05  LAL vs. DET  W         7.0
# 7348  Los Angeles Lakers  0021900553 2020-01-07  LAL vs. NYK  W        30.0
# 7304  Los Angeles Lakers  0021900572 2020-01-10    LAL @ DAL  W        15.0
# 7297  Los Angeles Lakers  0021900580 2020-01-11    LAL @ OKC  W        15.0
# 7270  Los Angeles Lakers  0021900597 2020-01-13  LAL vs. CLE  W        29.0
# 7239  Los Angeles Lakers  0021900613 2020-01-15  LAL vs. ORL  L        -1.0
# 7183  Los Angeles Lakers  0021900633 2020-01-18    LAL @ HOU  W         9.0
# 7171  Los Angeles Lakers  0021900648 2020-01-20    LAL @ BOS  L       -32.0
# 7136  Los Angeles Lakers  0021900659 2020-01-22    LAL @ NYK  W         8.0
# 7121  Los Angeles Lakers  0021900667 2020-01-23    LAL @ BKN  W        15.0
# 7085  Los Angeles Lakers  0021900684 2020-01-25    LAL @ PHI  L       -17.0
# 7015  Los Angeles Lakers  0021900726 2020-01-31  LAL vs. POR  L        -8.0
# 6998  Los Angeles Lakers  0021900736 2020-02-01    LAL @ SAC  W        16.0
# 6949  Los Angeles Lakers  0021900754 2020-02-04  LAL vs. SAS  W        27.0
# 6923  Los Angeles Lakers  0021900768 2020-02-06  LAL vs. HOU  L       -10.0
# 6900  Los Angeles Lakers  0021900783 2020-02-08    LAL @ GSW  W         5.0
# 6869  Los Angeles Lakers  0021900801 2020-02-10  LAL vs. PHX  W        25.0
# 6837  Los Angeles Lakers  0021900817 2020-02-12    LAL @ DEN  W         4.0
# 6796  Los Angeles Lakers  0021900833 2020-02-21  LAL vs. MEM  W        12.0
# 6765  Los Angeles Lakers  0021900842 2020-02-23  LAL vs. BOS  W         2.0
# 6723  Los Angeles Lakers  0021900861 2020-02-25  LAL vs. NOP  W         9.0
# 6701  Los Angeles Lakers  0021900876 2020-02-27    LAL @ GSW  W        30.0
# 6665  Los Angeles Lakers  0021900891 2020-02-29    LAL @ MEM  L       -17.0
# 6646  Los Angeles Lakers  0021900900 2020-03-01    LAL @ NOP  W         8.0
# 6624  Los Angeles Lakers  0021900915 2020-03-03  LAL vs. PHI  W        13.0
# 6577  Los Angeles Lakers  0021900939 2020-03-06  LAL vs. MIL  W        10.0
# 6542  Los Angeles Lakers  0021900948 2020-03-08    LAL @ LAC  W         9.0
# 6523  Los Angeles Lakers  0021900968 2020-03-10  LAL vs. BKN  L        -2.0
# 6488  Los Angeles Lakers  0011900107 2020-07-23  LAL vs. DAL  L        -4.0
# 6470  Los Angeles Lakers  0011900112 2020-07-25    LAL @ ORL  W         7.0
# 6458  Los Angeles Lakers  0011900123 2020-07-27  LAL vs. WAS  W         7.0
# 6434  Los Angeles Lakers  0021901232 2020-07-30  LAL vs. LAC  W         2.0
# 6421  Los Angeles Lakers  0021901243 2020-08-01    LAL @ TOR  L       -15.0
#
#       avg_30_plus_minus
# 7443                NaN
# 7416                NaN
# 7378                NaN
# 7348                NaN
# 7304                NaN
# 7297                NaN
# 7270                NaN
# 7239                NaN
# 7183                NaN
# 7171                NaN
# 7136                NaN
# 7121                NaN
# 7085                NaN
# 7015                NaN
# 6998                NaN
# 6949                NaN
# 6923                NaN
# 6900                NaN
# 6869                NaN
# 6837                NaN
# 6796                NaN
# 6765                NaN
# 6723                NaN
# 6701                NaN
# 6665                NaN
# 6646                NaN
# 6624                NaN
# 6577                NaN
# 6542                NaN
# 6523                NaN
# 6488           7.700000
# 6470           7.233333
# 6458           7.133333
# 6434           7.133333
# 6421           6.200000

# %%
msk = games['MATCHUP'].str.contains('@')
games_away = games[msk]
games_home = games[~msk]

# %%
games_home.shape
# Out:
# (3723, 7)

# %%
games_away.shape
# Out:
# (3723, 7)

# %%
games_home
# Out:
#                 TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  PLUS_MINUS  \
# 7438      Milwaukee Bucks  0021900506 2020-01-01  MIL vs. MIN  W         2.0
# 7442   Washington Wizards  0021900504 2020-01-01  WAS vs. ORL  L       -21.0
# 7443   Los Angeles Lakers  0021900507 2020-01-01  LAL vs. PHX  W        10.0
# 7441      New York Knicks  0021900505 2020-01-01  NYK vs. POR  W        24.0
# 7422        Chicago Bulls  0021900511 2020-01-02  CHI vs. UTA  L        -4.0
# ...                   ...         ...        ...          ... ..         ...
# 21          Atlanta Hawks  0022200354 2022-12-05  ATL vs. OKC  L        -7.0
# 13      Memphis Grizzlies  0022200357 2022-12-05  MEM vs. MIA  W         8.0
# 5              Miami Heat  0022200361 2022-12-06  MIA vs. DET  L       -20.0
# 4          Denver Nuggets  0022200362 2022-12-06  DEN vs. DAL  L        -1.0
# 2     Cleveland Cavaliers  0022200360 2022-12-06  CLE vs. LAL  W        14.0
#
#       avg_30_plus_minus
# 7438                NaN
# 7442                NaN
# 7443                NaN
# 7441                NaN
# 7422                NaN
# ...                 ...
# 21             0.193333
# 13             3.000000
# 5              0.533333
# 4              0.513333
# 2              3.926667
#
# [3723 rows x 7 columns]

# %%
games_away
# Out:
#                    TEAM_NAME     GAME_ID  GAME_DATE    MATCHUP WL  PLUS_MINUS  \
# 7445  Portland Trail Blazers  0021900505 2020-01-01  POR @ NYK  L       -24.0
# 7439            Phoenix Suns  0021900507 2020-01-01  PHX @ LAL  L       -10.0
# 7440  Minnesota Timberwolves  0021900506 2020-01-01  MIN @ MIL  L        -2.0
# 7444           Orlando Magic  0021900504 2020-01-01  ORL @ WAS  W        21.0
# 7420       Memphis Grizzlies  0021900515 2020-01-02  MEM @ SAC  L        -5.0
# ...                      ...         ...        ...        ... ..         ...
# 19              Phoenix Suns  0022200358 2022-12-05  PHX @ DAL  L       -19.0
# 20        Philadelphia 76ers  0022200356 2022-12-05  PHI @ HOU  L        -9.0
# 3         Los Angeles Lakers  0022200360 2022-12-06  LAL @ CLE  L       -14.0
# 1            Detroit Pistons  0022200361 2022-12-06  DET @ MIA  W        20.0
# 0           Dallas Mavericks  0022200362 2022-12-06  DAL @ DEN  W         1.0
#
#       avg_30_plus_minus
# 7445                NaN
# 7439                NaN
# 7440                NaN
# 7444                NaN
# 7420                NaN
# ...                 ...
# 19             5.100000
# 20             1.533333
# 3             -2.466667
# 1             -9.066667
# 0              2.100000
#
# [3723 rows x 7 columns]

# %%
games_merged = pd.merge(games_home, games_away, on='GAME_ID', suffixes=('_home', '_away'))
games_merged
# Out:
#            TEAM_NAME_home     GAME_ID GAME_DATE_home MATCHUP_home WL_home  \
# 0         Milwaukee Bucks  0021900506     2020-01-01  MIL vs. MIN       W
# 1      Washington Wizards  0021900504     2020-01-01  WAS vs. ORL       L
# 2      Los Angeles Lakers  0021900507     2020-01-01  LAL vs. PHX       W
# 3         New York Knicks  0021900505     2020-01-01  NYK vs. POR       W
# 4           Chicago Bulls  0021900511     2020-01-02  CHI vs. UTA       L
# ...                   ...         ...            ...          ...     ...
# 3718        Atlanta Hawks  0022200354     2022-12-05  ATL vs. OKC       L
# 3719    Memphis Grizzlies  0022200357     2022-12-05  MEM vs. MIA       W
# 3720           Miami Heat  0022200361     2022-12-06  MIA vs. DET       L
# 3721       Denver Nuggets  0022200362     2022-12-06  DEN vs. DAL       L
# 3722  Cleveland Cavaliers  0022200360     2022-12-06  CLE vs. LAL       W
#
#       PLUS_MINUS_home  avg_30_plus_minus_home          TEAM_NAME_away  \
# 0                 2.0                     NaN  Minnesota Timberwolves
# 1               -21.0                     NaN           Orlando Magic
# 2                10.0                     NaN            Phoenix Suns
# 3                24.0                     NaN  Portland Trail Blazers
# 4                -4.0                     NaN               Utah Jazz
# ...               ...                     ...                     ...
# 3718             -7.0                0.193333   Oklahoma City Thunder
# 3719              8.0                3.000000              Miami Heat
# 3720            -20.0                0.533333         Detroit Pistons
# 3721             -1.0                0.513333        Dallas Mavericks
# 3722             14.0                3.926667      Los Angeles Lakers
#
#      GAME_DATE_away MATCHUP_away WL_away  PLUS_MINUS_away  \
# 0        2020-01-01    MIN @ MIL       L             -2.0
# 1        2020-01-01    ORL @ WAS       W             21.0
# 2        2020-01-01    PHX @ LAL       L            -10.0
# 3        2020-01-01    POR @ NYK       L            -24.0
# 4        2020-01-02    UTA @ CHI       W              4.0
# ...             ...          ...     ...              ...
# 3718     2022-12-05    OKC @ ATL       W              7.0
# 3719     2022-12-05    MIA @ MEM       L             -8.0
# 3720     2022-12-06    DET @ MIA       W             20.0
# 3721     2022-12-06    DAL @ DEN       W              1.0
# 3722     2022-12-06    LAL @ CLE       L            -14.0
#
#       avg_30_plus_minus_away
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 3718                1.233333
# 3719                1.066667
# 3720               -9.066667
# 3721                2.100000
# 3722               -2.466667
#
# [3723 rows x 13 columns]

# %%
games_merged['avg_30_plus_minus_diff'] = games_merged['avg_30_plus_minus_home'] - games_merged['avg_30_plus_minus_away']

# %%
games_merged
# Out:
#            TEAM_NAME_home     GAME_ID GAME_DATE_home MATCHUP_home WL_home  \
# 0         Milwaukee Bucks  0021900506     2020-01-01  MIL vs. MIN       W
# 1      Washington Wizards  0021900504     2020-01-01  WAS vs. ORL       L
# 2      Los Angeles Lakers  0021900507     2020-01-01  LAL vs. PHX       W
# 3         New York Knicks  0021900505     2020-01-01  NYK vs. POR       W
# 4           Chicago Bulls  0021900511     2020-01-02  CHI vs. UTA       L
# ...                   ...         ...            ...          ...     ...
# 3718        Atlanta Hawks  0022200354     2022-12-05  ATL vs. OKC       L
# 3719    Memphis Grizzlies  0022200357     2022-12-05  MEM vs. MIA       W
# 3720           Miami Heat  0022200361     2022-12-06  MIA vs. DET       L
# 3721       Denver Nuggets  0022200362     2022-12-06  DEN vs. DAL       L
# 3722  Cleveland Cavaliers  0022200360     2022-12-06  CLE vs. LAL       W
#
#       PLUS_MINUS_home  avg_30_plus_minus_home          TEAM_NAME_away  \
# 0                 2.0                     NaN  Minnesota Timberwolves
# 1               -21.0                     NaN           Orlando Magic
# 2                10.0                     NaN            Phoenix Suns
# 3                24.0                     NaN  Portland Trail Blazers
# 4                -4.0                     NaN               Utah Jazz
# ...               ...                     ...                     ...
# 3718             -7.0                0.193333   Oklahoma City Thunder
# 3719              8.0                3.000000              Miami Heat
# 3720            -20.0                0.533333         Detroit Pistons
# 3721             -1.0                0.513333        Dallas Mavericks
# 3722             14.0                3.926667      Los Angeles Lakers
#
#      GAME_DATE_away MATCHUP_away WL_away  PLUS_MINUS_away  \
# 0        2020-01-01    MIN @ MIL       L             -2.0
# 1        2020-01-01    ORL @ WAS       W             21.0
# 2        2020-01-01    PHX @ LAL       L            -10.0
# 3        2020-01-01    POR @ NYK       L            -24.0
# 4        2020-01-02    UTA @ CHI       W              4.0
# ...             ...          ...     ...              ...
# 3718     2022-12-05    OKC @ ATL       W              7.0
# 3719     2022-12-05    MIA @ MEM       L             -8.0
# 3720     2022-12-06    DET @ MIA       W             20.0
# 3721     2022-12-06    DAL @ DEN       W              1.0
# 3722     2022-12-06    LAL @ CLE       L            -14.0
#
#       avg_30_plus_minus_away  avg_30_plus_minus_diff
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 3718                1.233333               -1.040000
# 3719                1.066667                1.933333
# 3720               -9.066667                9.600000
# 3721                2.100000               -1.586667
# 3722               -2.466667                6.393333
#
# [3723 rows x 14 columns]

# %%
games_merged[['WL_home', 'avg_30_plus_minus_diff']]
# Out:
#      WL_home  avg_30_plus_minus_diff
# 0          W                     NaN
# 1          L                     NaN
# 2          W                     NaN
# 3          W                     NaN
# 4          L                     NaN
# ...      ...                     ...
# 3718       L               -1.040000
# 3719       W                1.933333
# 3720       L                9.600000
# 3721       L               -1.586667
# 3722       W                6.393333
#
# [3723 rows x 2 columns]

# %%
games_model = games_merged[['WL_home', 'avg_30_plus_minus_diff']].dropna()
games_model
# Out:
#      WL_home  avg_30_plus_minus_diff
# 445        W               -1.800000
# 450        L                0.733333
# 453        L               -6.200000
# 458        L               -4.433333
# 459        W               -0.466667
# ...      ...                     ...
# 3718       L               -1.040000
# 3719       W                1.933333
# 3720       L                9.600000
# 3721       L               -1.586667
# 3722       W                6.393333
#
# [3249 rows x 2 columns]

# %%
games_model['WL_home'] = games_model['WL_home'].map({'W': 1, 'L': 0})

# %%
games_model
# Out:
#       WL_home  avg_30_plus_minus_diff
# 445         1               -1.800000
# 450         0                0.733333
# 453         0               -6.200000
# 458         0               -4.433333
# 459         1               -0.466667
# ...       ...                     ...
# 3718        0               -1.040000
# 3719        1                1.933333
# 3720        0                9.600000
# 3721        0               -1.586667
# 3722        1                6.393333
#
# [3249 rows x 2 columns]

# %% [markdown]
# ## Building the Model

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(games_model, stratify=games_model['WL_home'], test_size=0.2, random_state=7)

# %%
df_train.shape
# Out:
# (2599, 2)

# %%
df_test.shape
# Out:
# (650, 2)

# %%
target = 'WL_home'
X_train = df_train.drop(columns=target)
y_train = df_train[target]

X_test = df_test.drop(columns=target)
y_test= df_test[target]

# %% [markdown]
# Let us use the various Classification Algorithms to identify which gives us the highest accuracy

# %%
xgb_clf = xgb.XGBClassifier(use_label_encoder=False, random_state=7)

# %%
xgb_clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=7, ...)

# %%
y_pred = xgb_clf.predict(X_test)

# %%
xgb_score = accuracy_score(y_test, y_pred)
xgb_score
# Out:
# 0.5892307692307692

# %%
xgb_hyp_params = {'learning_rate': loguniform(0.0001, 1),
              'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
              'subsample': [0.7, 0.8, 0.9, 1.0],
              'n_estimators': [50, 100, 150, 200]}

# %%
random_hyp = RandomizedSearchCV(estimator=xgb_clf, 
                                param_distributions=xgb_hyp_params, 
                                n_iter=20, 
                                cv=7,
                                scoring='accuracy',
                                random_state=7)

# %%
random_hyp.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=7,
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            callbacks=None, colsample_bylevel=1,
#                                            colsample_bynode=1,
#                                            colsample_bytree=1,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=0, gpu_id=-1,
#                                            grow_policy='depthwise',
#                                            importance_type=None,
#                                            interaction_constraints='',
#                                            learning_rate=0.300...
#                                            monotone_constraints='()',
#                                            n_estimators=100, n_jobs=0,
#                                            num_parallel_tree=1,
#                                            predictor='auto', random_state=7, ...),
#                    n_iter=20,
#                    param_distributions={'learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x0000017DDFC22AF0>,
#                                         'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
#                                         'n_estimators': [50, 100, 150, 200],
#                                         'subsample': [0.7, 0.8, 0.9, 1.0]},
#                    random_state=7, scoring='accuracy')

# %%
random_hyp.best_params_
# Out:
# {'learning_rate': 0.0002019450244810229,
#  'max_depth': 3,
#  'n_estimators': 150,
#  'subsample': 1.0}

# %%
model_hyp = random_hyp.best_estimator_

# %%
y_pred_hyp = model_hyp.predict(X_test)

# %%
rs_score = accuracy_score(y_test, y_pred_hyp)

# %%
from joblib import dump, load
dump(model_hyp, 'model_nba.joblib') 
model_saved = load('model_nba.joblib')

# %%
accuracy_score(y_test, model_saved.predict(X_test))
# Out:
# 0.64

# %%
from nba_api.stats.endpoints import leaguegamefinder
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/01/2020', league_id_nullable='00')
games = gamefinder.get_data_frames()[0]

games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]

import pandas as pd

games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

games = games.sort_values('GAME_DATE')

games['avg_30_plus_minus'] = games.groupby('TEAM_NAME')['PLUS_MINUS'].transform(lambda x: x.rolling(30, closed='left').mean())

msk = games['MATCHUP'].str.contains('@')
games_away = games[msk]
games_home = games[~msk]

games_merged = pd.merge(games_home, games_away, on='GAME_ID', suffixes=('_home', '_away'))

games_merged['avg_30_plus_minus_diff'] = games_merged['avg_30_plus_minus_home'] - games_merged['avg_30_plus_minus_away']

# %%
team_home='Toronto Raptors'
team_away='Boston Celtics'

import numpy as np
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/01/2020',
                                           league_id_nullable='00')
games = gamefinder.get_data_frames()[0]
games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]
games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

msk_home = (games['TEAM_NAME'] == team_home)
games_30_home = games[msk_home].sort_values('GAME_DATE').tail(30)
home_plus_minus = games_30_home['PLUS_MINUS'].mean()

msk_away = (games['TEAM_NAME'] == team_away)
games_30_away = games[msk_away].sort_values('GAME_DATE').tail(30)
away_plus_minus = games_30_away['PLUS_MINUS'].mean()

games_diff=home_plus_minus - away_plus_minus

predict_home_win=model_saved.predict(np.array([games_diff]))[0]
predict_winning_probability=model_saved.predict_proba(np.array([games_diff]))[0][1]

# %%
def predict_games(team_home, team_away):
    gamefinder = leaguegamefinder.LeagueGameFinder(
        date_from_nullable='01/01/2020',
        league_id_nullable='00')
    games = gamefinder.get_data_frames()[0]
    games = games[
        ['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]
    games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

    msk_home = (games['TEAM_NAME'] == team_home)
    games_30_home = games[msk_home].sort_values('GAME_DATE').tail(30)
    home_plus_minus = games_30_home['PLUS_MINUS'].mean()

    msk_away = (games['TEAM_NAME'] == team_away)
    games_30_away = games[msk_away].sort_values('GAME_DATE').tail(30)
    away_plus_minus = games_30_away['PLUS_MINUS'].mean()

    games_diff = home_plus_minus - away_plus_minus

    predict_home_win = model_saved.predict(np.array([games_diff]))[0]
    predict_winning_probability = model_saved.predict_proba(np.array([games_diff]))[0][1]
    return predict_home_win, predict_winning_probability

# %%
predict_games('Boston Celtics','Toronto Raptors')
# Out:
# (1, 0.5068216)
