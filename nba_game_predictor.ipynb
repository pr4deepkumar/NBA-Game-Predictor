# %% [markdown]
# ## NBA Game Predictor
#
# This project is designed to predict the winner in a potential matchup

# %% [markdown]
# Let us import the API to be used

# %%
# %pip install nba-api
# Out:
# Requirement already satisfied: nba-api in d:\myapps\anaconda3\lib\site-packages (1.4.1)
# Requirement already satisfied: certifi<2024.0.0,>=2023.7.22 in d:\myapps\anaconda3\lib\site-packages (from nba-api) (2023.7.22)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in d:\myapps\anaconda3\lib\site-packages (from nba-api) (1.24.3)
# Requirement already satisfied: requests<3.0,>=2.31 in d:\myapps\anaconda3\lib\site-packages (from nba-api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\myapps\anaconda3\lib\site-packages (from requests<3.0,>=2.31->nba-api) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\myapps\anaconda3\lib\site-packages (from requests<3.0,>=2.31->nba-api) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\myapps\anaconda3\lib\site-packages (from requests<3.0,>=2.31->nba-api) (1.26.16)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now, we shall import the necessary packages

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# for classification
import xgboost as xgb
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import loguniform

# for metrics
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Games Predictor

# %%
from nba_api.stats.endpoints import leaguegamefinder
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable="10/18/2022",league_id_nullable="00")
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION             TEAM_NAME     GAME_ID  \
# 0     22023  1610612766               CHA     Charlotte Hornets  0022300745
# 1     22023  1610612740               NOP  New Orleans Pelicans  0022300747
# 2     22023  1610612761               TOR       Toronto Raptors  0022300744
# 3     22023  1610612758               SAC      Sacramento Kings  0022300746
# 4     22023  1610612745               HOU       Houston Rockets  0022300744
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 0  2024-02-09    CHA @ MIL  L  239   84   27   79   0.342     7    29
# 1  2024-02-09    NOP @ LAL  L  241  122   46   89   0.517    11    29
# 2  2024-02-09  TOR vs. HOU  W  240  107   40   95   0.421    10    33
# 3  2024-02-09  SAC vs. DEN  W  242  135   51   87   0.586    17    34
# 4  2024-02-09    HOU @ TOR  L  240  104   38   85   0.447    15    38
#
#    FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0    0.241   23   29   0.793     8    40   48   17    2    2   13  20
# 1    0.379   19   23   0.826    10    31   41   28    5    7   13  22
# 2    0.303   17   19   0.895    16    25   41   24   14    8   11  17
# 3    0.500   16   18   0.889     6    36   42   32   11    1   16  22
# 4    0.395   13   16   0.813    12    36   48   22    5    3   21  20
#
#    PLUS_MINUS
# 0       -36.0
# 1       -17.0
# 2         3.0
# 3        29.0
# 4        -3.0

# %%
games.columns
# Out:
# Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')

# %%
games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]

# %%
games
# Out:
#                   TEAM_NAME     GAME_ID   GAME_DATE      MATCHUP WL  \
# 0         Charlotte Hornets  0022300745  2024-02-09    CHA @ MIL  L
# 1      New Orleans Pelicans  0022300747  2024-02-09    NOP @ LAL  L
# 2           Toronto Raptors  0022300744  2024-02-09  TOR vs. HOU  W
# 3          Sacramento Kings  0022300746  2024-02-09  SAC vs. DEN  W
# 4           Houston Rockets  0022300744  2024-02-09    HOU @ TOR  L
# ...                     ...         ...         ...          ... ..
# 4344          Atlanta Hawks  0022200005  2022-10-19  ATL vs. HOU  W
# 4345         Boston Celtics  0022200001  2022-10-18  BOS vs. PHI  W
# 4346  Golden State Warriors  0022200002  2022-10-18  GSW vs. LAL  W
# 4347     Los Angeles Lakers  0022200002  2022-10-18    LAL @ GSW  L
# 4348     Philadelphia 76ers  0022200001  2022-10-18    PHI @ BOS  L
#
#       PLUS_MINUS
# 0          -36.0
# 1          -17.0
# 2            3.0
# 3           29.0
# 4           -3.0
# ...          ...
# 4344        10.0
# 4345         9.0
# 4346        14.0
# 4347       -14.0
# 4348        -9.0
#
# [4349 rows x 6 columns]

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4349 entries, 0 to 4348
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TEAM_NAME   4349 non-null   object
#  1   GAME_ID     4349 non-null   object
#  2   GAME_DATE   4349 non-null   object
#  3   MATCHUP     4349 non-null   object
#  4   WL          4348 non-null   object
#  5   PLUS_MINUS  4349 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 204.0+ KB

# %%
games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

# %%
games['GAME_DATE']
# Out:
# 0      2024-02-09
# 1      2024-02-09
# 2      2024-02-09
# 3      2024-02-09
# 4      2024-02-09
#           ...
# 4344   2022-10-19
# 4345   2022-10-18
# 4346   2022-10-18
# 4347   2022-10-18
# 4348   2022-10-18
# Name: GAME_DATE, Length: 4349, dtype: datetime64[ns]

# %%
games = games.sort_values('GAME_DATE')
games
# Out:
#                   TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  PLUS_MINUS
# 4348     Philadelphia 76ers  0022200001 2022-10-18    PHI @ BOS  L        -9.0
# 4345         Boston Celtics  0022200001 2022-10-18  BOS vs. PHI  W         9.0
# 4347     Los Angeles Lakers  0022200002 2022-10-18    LAL @ GSW  L       -14.0
# 4346  Golden State Warriors  0022200002 2022-10-18  GSW vs. LAL  W        14.0
# 4344          Atlanta Hawks  0022200005 2022-10-19  ATL vs. HOU  W        10.0
# ...                     ...         ...        ...          ... ..         ...
# 8             Atlanta Hawks  0022300742 2024-02-09    ATL @ PHI  W         6.0
# 10       Los Angeles Lakers  0022300747 2024-02-09  LAL vs. NOP  W        17.0
# 11           Denver Nuggets  0022300746 2024-02-09    DEN @ SAC  L       -29.0
# 6        Philadelphia 76ers  0022300742 2024-02-09  PHI vs. ATL  L        -6.0
# 0         Charlotte Hornets  0022300745 2024-02-09    CHA @ MIL  L       -36.0
#
# [4349 rows x 6 columns]

# %%
games['avg_30_plus_minus'] = games.groupby('TEAM_NAME')['PLUS_MINUS'].transform(lambda x: x.rolling(30, closed='left').mean())

# %%
games
# Out:
#                   TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  \
# 4348     Philadelphia 76ers  0022200001 2022-10-18    PHI @ BOS  L
# 4345         Boston Celtics  0022200001 2022-10-18  BOS vs. PHI  W
# 4347     Los Angeles Lakers  0022200002 2022-10-18    LAL @ GSW  L
# 4346  Golden State Warriors  0022200002 2022-10-18  GSW vs. LAL  W
# 4344          Atlanta Hawks  0022200005 2022-10-19  ATL vs. HOU  W
# ...                     ...         ...        ...          ... ..
# 8             Atlanta Hawks  0022300742 2024-02-09    ATL @ PHI  W
# 10       Los Angeles Lakers  0022300747 2024-02-09  LAL vs. NOP  W
# 11           Denver Nuggets  0022300746 2024-02-09    DEN @ SAC  L
# 6        Philadelphia 76ers  0022300742 2024-02-09  PHI vs. ATL  L
# 0         Charlotte Hornets  0022300745 2024-02-09    CHA @ MIL  L
#
#       PLUS_MINUS  avg_30_plus_minus
# 4348        -9.0                NaN
# 4345         9.0                NaN
# 4347       -14.0                NaN
# 4346        14.0                NaN
# 4344        10.0                NaN
# ...          ...                ...
# 8            6.0          -3.933333
# 10          17.0          -2.700000
# 11         -29.0           4.833333
# 6           -6.0           3.400000
# 0          -36.0         -14.233333
#
# [4349 rows x 7 columns]

# %%
games[games['TEAM_NAME']=='Los Angeles Lakers'].head(35)
# Out:
#                TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  PLUS_MINUS  \
# 4347  Los Angeles Lakers  0022200002 2022-10-18    LAL @ GSW  L       -14.0
# 4317  Los Angeles Lakers  0022200016 2022-10-20  LAL vs. LAC  L        -6.0
# 4264  Los Angeles Lakers  0022200037 2022-10-23  LAL vs. POR  L        -2.0
# 4231  Los Angeles Lakers  0022200064 2022-10-26    LAL @ DEN  L       -11.0
# 4210  Los Angeles Lakers  0022200076 2022-10-28    LAL @ MIN  L        -9.0
# 4166  Los Angeles Lakers  0022200095 2022-10-30  LAL vs. DEN  W        11.0
# 4130  Los Angeles Lakers  0022200117 2022-11-02  LAL vs. NOP  W         3.0
# 4103  Los Angeles Lakers  0022200131 2022-11-04  LAL vs. UTA  L       -14.0
# 4063  Los Angeles Lakers  0022200140 2022-11-06  LAL vs. CLE  L       -14.0
# 4051  Los Angeles Lakers  0022200157 2022-11-07    LAL @ UTA  L       -23.0
# 4014  Los Angeles Lakers  0022200170 2022-11-09    LAL @ LAC  L       -13.0
# 3995  Los Angeles Lakers  0022200183 2022-11-11  LAL vs. SAC  L        -6.0
# 3959  Los Angeles Lakers  0022200198 2022-11-13  LAL vs. BKN  W        13.0
# 3895  Los Angeles Lakers  0022200234 2022-11-18  LAL vs. DET  W         7.0
# 3863  Los Angeles Lakers  0022200247 2022-11-20  LAL vs. SAS  W        31.0
# 3838  Los Angeles Lakers  0022200259 2022-11-22    LAL @ PHX  L       -10.0
# 3799  Los Angeles Lakers  0022200282 2022-11-25    LAL @ SAS  W        11.0
# 3773  Los Angeles Lakers  0022200288 2022-11-26    LAL @ SAS  W         5.0
# 3748  Los Angeles Lakers  0022200308 2022-11-28  LAL vs. IND  L        -1.0
# 3706  Los Angeles Lakers  0022200324 2022-11-30  LAL vs. POR  W        19.0
# 3697  Los Angeles Lakers  0022200331 2022-12-02    LAL @ MIL  W         4.0
# 3656  Los Angeles Lakers  0022200349 2022-12-04    LAL @ WAS  W        11.0
# 3628  Los Angeles Lakers  0022200360 2022-12-06    LAL @ CLE  L       -14.0
# 3608  Los Angeles Lakers  0022200366 2022-12-07    LAL @ TOR  L       -13.0
# 3592  Los Angeles Lakers  0022200382 2022-12-09    LAL @ PHI  L       -11.0
# 3547  Los Angeles Lakers  0022200396 2022-12-11    LAL @ DET  W         7.0
# 3524  Los Angeles Lakers  0022200413 2022-12-13  LAL vs. BOS  L        -4.0
# 3491  Los Angeles Lakers  0022200437 2022-12-16  LAL vs. DEN  W        18.0
# 3447  Los Angeles Lakers  0022200451 2022-12-18  LAL vs. WAS  W         2.0
# 3430  Los Angeles Lakers  0022200459 2022-12-19    LAL @ PHX  L       -26.0
# 3403  Los Angeles Lakers  0022200475 2022-12-21    LAL @ SAC  L       -14.0
# 3367  Los Angeles Lakers  0022200492 2022-12-23  LAL vs. CHA  L        -4.0
# 3360  Los Angeles Lakers  0022200494 2022-12-25    LAL @ DAL  L        -9.0
# 3331  Los Angeles Lakers  0022200505 2022-12-27    LAL @ ORL  W        19.0
# 3314  Los Angeles Lakers  0022200518 2022-12-28    LAL @ MIA  L       -14.0
#
#       avg_30_plus_minus
# 4347                NaN
# 4317                NaN
# 4264                NaN
# 4231                NaN
# 4210                NaN
# 4166                NaN
# 4130                NaN
# 4103                NaN
# 4063                NaN
# 4051                NaN
# 4014                NaN
# 3995                NaN
# 3959                NaN
# 3895                NaN
# 3863                NaN
# 3838                NaN
# 3799                NaN
# 3773                NaN
# 3748                NaN
# 3706                NaN
# 3697                NaN
# 3656                NaN
# 3628                NaN
# 3608                NaN
# 3592                NaN
# 3547                NaN
# 3524                NaN
# 3491                NaN
# 3447                NaN
# 3430                NaN
# 3403          -1.633333
# 3367          -1.633333
# 3360          -1.566667
# 3331          -1.800000
# 3314          -0.800000

# %%
msk = games['MATCHUP'].str.contains('@')
games_away = games[msk]
games_home = games[~msk]

# %%
games_home.shape
# Out:
# (2175, 7)

# %%
games_away.shape
# Out:
# (2174, 7)

# %%
games_home
# Out:
#                   TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  \
# 4345         Boston Celtics  0022200001 2022-10-18  BOS vs. PHI  W
# 4346  Golden State Warriors  0022200002 2022-10-18  GSW vs. LAL  W
# 4344          Atlanta Hawks  0022200005 2022-10-19  ATL vs. HOU  W
# 4326         Indiana Pacers  0022200004 2022-10-19  IND vs. WAS  L
# 4327      Memphis Grizzlies  0022200009 2022-10-19  MEM vs. NYK  W
# ...                     ...         ...        ...          ... ..
# 3          Sacramento Kings  0022300746 2024-02-09  SAC vs. DEN  W
# 5           Milwaukee Bucks  0022300745 2024-02-09  MIL vs. CHA  W
# 9            Boston Celtics  0022300743 2024-02-09  BOS vs. WAS  W
# 10       Los Angeles Lakers  0022300747 2024-02-09  LAL vs. NOP  W
# 6        Philadelphia 76ers  0022300742 2024-02-09  PHI vs. ATL  L
#
#       PLUS_MINUS  avg_30_plus_minus
# 4345         9.0                NaN
# 4346        14.0                NaN
# 4344        10.0                NaN
# 4326        -7.0                NaN
# 4327         3.0                NaN
# ...          ...                ...
# 3           29.0           0.593333
# 5           36.0           2.633333
# 9            4.0          10.400000
# 10          17.0          -2.700000
# 6           -6.0           3.400000
#
# [2175 rows x 7 columns]

# %%
games_away
# Out:
#                TEAM_NAME     GAME_ID  GAME_DATE    MATCHUP WL  PLUS_MINUS  \
# 4348  Philadelphia 76ers  0022200001 2022-10-18  PHI @ BOS  L        -9.0
# 4347  Los Angeles Lakers  0022200002 2022-10-18  LAL @ GSW  L       -14.0
# 4321     Houston Rockets  0022200005 2022-10-19  HOU @ ATL  L       -10.0
# 4322   Charlotte Hornets  0022200011 2022-10-19  CHA @ SAS  W        27.0
# 4323    Dallas Mavericks  0022200013 2022-10-19  DAL @ PHX  L        -2.0
# ...                  ...         ...        ...        ... ..         ...
# 4        Houston Rockets  0022300744 2024-02-09  HOU @ TOR  L        -3.0
# 7     Washington Wizards  0022300743 2024-02-09  WAS @ BOS  L        -4.0
# 8          Atlanta Hawks  0022300742 2024-02-09  ATL @ PHI  W         6.0
# 11        Denver Nuggets  0022300746 2024-02-09  DEN @ SAC  L       -29.0
# 0      Charlotte Hornets  0022300745 2024-02-09  CHA @ MIL  L       -36.0
#
#       avg_30_plus_minus
# 4348                NaN
# 4347                NaN
# 4321                NaN
# 4322                NaN
# 4323                NaN
# ...                 ...
# 4             -0.866667
# 7            -10.100000
# 8             -3.933333
# 11             4.833333
# 0            -14.233333
#
# [2174 rows x 7 columns]

# %%
games_merged = pd.merge(games_home, games_away, on='GAME_ID', suffixes=('_home', '_away'))
games_merged
# Out:
#              TEAM_NAME_home     GAME_ID GAME_DATE_home MATCHUP_home WL_home  \
# 0            Boston Celtics  0022200001     2022-10-18  BOS vs. PHI       W
# 1     Golden State Warriors  0022200002     2022-10-18  GSW vs. LAL       W
# 2             Atlanta Hawks  0022200005     2022-10-19  ATL vs. HOU       W
# 3            Indiana Pacers  0022200004     2022-10-19  IND vs. WAS       L
# 4         Memphis Grizzlies  0022200009     2022-10-19  MEM vs. NYK       W
# ...                     ...         ...            ...          ...     ...
# 2170       Sacramento Kings  0022300746     2024-02-09  SAC vs. DEN       W
# 2171        Milwaukee Bucks  0022300745     2024-02-09  MIL vs. CHA       W
# 2172         Boston Celtics  0022300743     2024-02-09  BOS vs. WAS       W
# 2173     Los Angeles Lakers  0022300747     2024-02-09  LAL vs. NOP       W
# 2174     Philadelphia 76ers  0022300742     2024-02-09  PHI vs. ATL       L
#
#       PLUS_MINUS_home  avg_30_plus_minus_home        TEAM_NAME_away  \
# 0                 9.0                     NaN    Philadelphia 76ers
# 1                14.0                     NaN    Los Angeles Lakers
# 2                10.0                     NaN       Houston Rockets
# 3                -7.0                     NaN    Washington Wizards
# 4                 3.0                     NaN       New York Knicks
# ...               ...                     ...                   ...
# 2170             29.0                0.593333        Denver Nuggets
# 2171             36.0                2.633333     Charlotte Hornets
# 2172              4.0               10.400000    Washington Wizards
# 2173             17.0               -2.700000  New Orleans Pelicans
# 2174             -6.0                3.400000         Atlanta Hawks
#
#      GAME_DATE_away MATCHUP_away WL_away  PLUS_MINUS_away  \
# 0        2022-10-18    PHI @ BOS       L             -9.0
# 1        2022-10-18    LAL @ GSW       L            -14.0
# 2        2022-10-19    HOU @ ATL       L            -10.0
# 3        2022-10-19    WAS @ IND       W              7.0
# 4        2022-10-19    NYK @ MEM       L             -3.0
# ...             ...          ...     ...              ...
# 2170     2024-02-09    DEN @ SAC       L            -29.0
# 2171     2024-02-09    CHA @ MIL       L            -36.0
# 2172     2024-02-09    WAS @ BOS       L             -4.0
# 2173     2024-02-09    NOP @ LAL       L            -17.0
# 2174     2024-02-09    ATL @ PHI       W              6.0
#
#       avg_30_plus_minus_away
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 2170                4.833333
# 2171              -14.233333
# 2172              -10.100000
# 2173                6.933333
# 2174               -3.933333
#
# [2175 rows x 13 columns]

# %%
games_merged['avg_30_plus_minus_diff'] = games_merged['avg_30_plus_minus_home'] - games_merged['avg_30_plus_minus_away']

# %%
games_merged
# Out:
#              TEAM_NAME_home     GAME_ID GAME_DATE_home MATCHUP_home WL_home  \
# 0            Boston Celtics  0022200001     2022-10-18  BOS vs. PHI       W
# 1     Golden State Warriors  0022200002     2022-10-18  GSW vs. LAL       W
# 2             Atlanta Hawks  0022200005     2022-10-19  ATL vs. HOU       W
# 3            Indiana Pacers  0022200004     2022-10-19  IND vs. WAS       L
# 4         Memphis Grizzlies  0022200009     2022-10-19  MEM vs. NYK       W
# ...                     ...         ...            ...          ...     ...
# 2170       Sacramento Kings  0022300746     2024-02-09  SAC vs. DEN       W
# 2171        Milwaukee Bucks  0022300745     2024-02-09  MIL vs. CHA       W
# 2172         Boston Celtics  0022300743     2024-02-09  BOS vs. WAS       W
# 2173     Los Angeles Lakers  0022300747     2024-02-09  LAL vs. NOP       W
# 2174     Philadelphia 76ers  0022300742     2024-02-09  PHI vs. ATL       L
#
#       PLUS_MINUS_home  avg_30_plus_minus_home        TEAM_NAME_away  \
# 0                 9.0                     NaN    Philadelphia 76ers
# 1                14.0                     NaN    Los Angeles Lakers
# 2                10.0                     NaN       Houston Rockets
# 3                -7.0                     NaN    Washington Wizards
# 4                 3.0                     NaN       New York Knicks
# ...               ...                     ...                   ...
# 2170             29.0                0.593333        Denver Nuggets
# 2171             36.0                2.633333     Charlotte Hornets
# 2172              4.0               10.400000    Washington Wizards
# 2173             17.0               -2.700000  New Orleans Pelicans
# 2174             -6.0                3.400000         Atlanta Hawks
#
#      GAME_DATE_away MATCHUP_away WL_away  PLUS_MINUS_away  \
# 0        2022-10-18    PHI @ BOS       L             -9.0
# 1        2022-10-18    LAL @ GSW       L            -14.0
# 2        2022-10-19    HOU @ ATL       L            -10.0
# 3        2022-10-19    WAS @ IND       W              7.0
# 4        2022-10-19    NYK @ MEM       L             -3.0
# ...             ...          ...     ...              ...
# 2170     2024-02-09    DEN @ SAC       L            -29.0
# 2171     2024-02-09    CHA @ MIL       L            -36.0
# 2172     2024-02-09    WAS @ BOS       L             -4.0
# 2173     2024-02-09    NOP @ LAL       L            -17.0
# 2174     2024-02-09    ATL @ PHI       W              6.0
#
#       avg_30_plus_minus_away  avg_30_plus_minus_diff
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 2170                4.833333               -4.240000
# 2171              -14.233333               16.866667
# 2172              -10.100000               20.500000
# 2173                6.933333               -9.633333
# 2174               -3.933333                7.333333
#
# [2175 rows x 14 columns]

# %%
games_merged[['WL_home', 'avg_30_plus_minus_diff']]
# Out:
#      WL_home  avg_30_plus_minus_diff
# 0          W                     NaN
# 1          W                     NaN
# 2          W                     NaN
# 3          L                     NaN
# 4          W                     NaN
# ...      ...                     ...
# 2170       W               -4.240000
# 2171       W               16.866667
# 2172       W               20.500000
# 2173       W               -9.633333
# 2174       L                7.333333
#
# [2175 rows x 2 columns]

# %%
games_model = games_merged[['WL_home', 'avg_30_plus_minus_diff']].dropna()
games_model
# Out:
#      WL_home  avg_30_plus_minus_diff
# 445        L               10.366667
# 448        L               -8.666667
# 451        W                3.213333
# 454        W               -2.500000
# 455        W                5.593333
# ...      ...                     ...
# 2170       W               -4.240000
# 2171       W               16.866667
# 2172       W               20.500000
# 2173       W               -9.633333
# 2174       L                7.333333
#
# [1702 rows x 2 columns]

# %%
games_model['WL_home'] = games_model['WL_home'].map({'W': 1, 'L': 0})

# %%
games_model
# Out:
#       WL_home  avg_30_plus_minus_diff
# 445         0               10.366667
# 448         0               -8.666667
# 451         1                3.213333
# 454         1               -2.500000
# 455         1                5.593333
# ...       ...                     ...
# 2170        1               -4.240000
# 2171        1               16.866667
# 2172        1               20.500000
# 2173        1               -9.633333
# 2174        0                7.333333
#
# [1702 rows x 2 columns]

# %% [markdown]
# ## Building the Model

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(games_model, stratify=games_model['WL_home'], test_size=0.2, random_state=7)

# %%
df_train.shape
# Out:
# (1361, 2)

# %%
df_test.shape
# Out:
# (341, 2)

# %%
target = 'WL_home'
X_train = df_train.drop(columns=target)
y_train = df_train[target]

X_test = df_test.drop(columns=target)
y_test= df_test[target]

# %% [markdown]
# Let us use the various Classification Algorithms to identify which gives us the highest accuracy

# %%
xgb_clf = xgb.XGBClassifier(use_label_encoder=False, random_state=7)

# %%
xgb_clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=7, ...)

# %%
y_pred = xgb_clf.predict(X_test)

# %%
xgb_score = accuracy_score(y_test, y_pred)
xgb_score
# Out:
# 0.624633431085044

# %%
xgb_hyp_params = {'learning_rate': loguniform(0.0001, 1),
              'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
              'subsample': [0.7, 0.8, 0.9, 1.0],
              'n_estimators': [50, 100, 150, 200]}

# %%
random_hyp = RandomizedSearchCV(estimator=xgb_clf, 
                                param_distributions=xgb_hyp_params, 
                                n_iter=20, 
                                cv=7,
                                scoring='accuracy',
                                random_state=7)

# %%
random_hyp.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=7,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
#                                            multi_strategy=None,
#                                            n_estimators=None, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            random_state=7, ...),
#                    n_iter=20,
#                    param_distributions={'learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x0000026999EE1C50>,
#                                         'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
#                                         'n_estimators': [50, 100, 150, 200],
#                                         'subsample': [0.7, 0.8, 0.9, 1.0]},
#                    random_state=7, scoring='accuracy')

# %%
random_hyp.best_params_
# Out:
# {'learning_rate': 0.004758705642828484,
#  'max_depth': 2,
#  'n_estimators': 200,
#  'subsample': 0.9}

# %%
model_hyp = random_hyp.best_estimator_

# %%
y_pred_hyp = model_hyp.predict(X_test)

# %%
rs_score = accuracy_score(y_test, y_pred_hyp)

# %%
from joblib import dump, load
dump(model_hyp, 'model_nba.joblib') 
model_saved = load('model_nba.joblib')

# %%
accuracy_score(y_test, model_saved.predict(X_test))
# Out:
# 0.6334310850439883

# %%
from nba_api.stats.endpoints import leaguegamefinder
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable="10/18/2022", league_id_nullable='00')
games = gamefinder.get_data_frames()[0]

games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]

import pandas as pd

games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

games = games.sort_values('GAME_DATE')

games['avg_30_plus_minus'] = games.groupby('TEAM_NAME')['PLUS_MINUS'].transform(lambda x: x.rolling(30, closed='left').mean())

msk = games['MATCHUP'].str.contains('@')
games_away = games[msk]
games_home = games[~msk]

games_merged = pd.merge(games_home, games_away, on='GAME_ID', suffixes=('_home', '_away'))

games_merged['avg_30_plus_minus_diff'] = games_merged['avg_30_plus_minus_home'] - games_merged['avg_30_plus_minus_away']

# %%
team_home='Toronto Raptors'
team_away='Boston Celtics'

import numpy as np
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='10/18/2022',
                                           league_id_nullable='00')
games = gamefinder.get_data_frames()[0]
games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]
games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

msk_home = (games['TEAM_NAME'] == team_home)
games_30_home = games[msk_home].sort_values('GAME_DATE').tail(30)
home_plus_minus = games_30_home['PLUS_MINUS'].mean()

msk_away = (games['TEAM_NAME'] == team_away)
games_30_away = games[msk_away].sort_values('GAME_DATE').tail(30)
away_plus_minus = games_30_away['PLUS_MINUS'].mean()

games_diff=home_plus_minus - away_plus_minus

predict_home_win=model_saved.predict(np.array([games_diff]))[0]
predict_winning_probability=model_saved.predict_proba(np.array([games_diff]))[0][1]

# %%
def predict_games(team_home, team_away):
    gamefinder = leaguegamefinder.LeagueGameFinder(
        date_from_nullable='10/18/2022',
        league_id_nullable='00')
    games = gamefinder.get_data_frames()[0]
    games = games[
        ['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]
    games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

    msk_home = (games['TEAM_NAME'] == team_home)
    games_30_home = games[msk_home].sort_values('GAME_DATE').tail(30)
    home_plus_minus = games_30_home['PLUS_MINUS'].mean()

    msk_away = (games['TEAM_NAME'] == team_away)
    games_30_away = games[msk_away].sort_values('GAME_DATE').tail(30)
    away_plus_minus = games_30_away['PLUS_MINUS'].mean()

    games_diff = home_plus_minus - away_plus_minus

    predict_home_win = model_saved.predict(np.array([games_diff]))[0]
    predict_winning_probability = model_saved.predict_proba(np.array([games_diff]))[0][1]
    return predict_home_win, predict_winning_probability

# %%
predict_games('Boston Celtics','Toronto Raptors')
# Out:
# (1, 0.698773)
